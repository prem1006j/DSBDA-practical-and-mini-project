# %%
# Run this once
# !pip install nltk scikit-learn

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# ...
# [nltk_data] Downloading package punkt to C:\Users\Prem Vilas
# [nltk_data]     Nikam/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Prem Vilas Nikam/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to C:\Users\Prem Vilas
# [nltk_data]     Nikam/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Prem Vilas
# [nltk_data]     Nikam/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
text = """Text analytics is the process of analyzing textual data to extract useful information.
It includes tokenization, stemming, lemmatization, and many other techniques."""

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')   # 🔥 IMPORTANT (new requirement)
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Prem Vilas
# [nltk_data]     Nikam/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Prem Vilas
# [nltk_data]     Nikam/nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Prem Vilas Nikam/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to C:\Users\Prem Vilas
# [nltk_data]     Nikam/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Prem Vilas
# [nltk_data]     Nikam/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

tokens = word_tokenize(text)
print(tokens)
# Out:
# ['Text', 'analytics', 'is', 'the', 'process', 'of', 'analyzing', 'textual', 'data', 'to', 'extract', 'useful', 'information', '.', 'It', 'includes', 'tokenization', ',', 'stemming', ',', 'lemmatization', ',', 'and', 'many', 'other', 'techniques', '.']

# %%
import nltk

# Old + new required resources
nltk.download('punkt')
nltk.download('punkt_tab')

nltk.download('averaged_perceptron_tagger')      # old
nltk.download('averaged_perceptron_tagger_eng')  # 🔥 new (important)

nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Prem Vilas
# [nltk_data]     Nikam/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Prem Vilas
# [nltk_data]     Nikam/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Prem Vilas Nikam/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Prem Vilas Nikam/nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package stopwords to C:\Users\Prem Vilas
# [nltk_data]     Nikam/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Prem Vilas
# [nltk_data]     Nikam/nltk_data...
# ...

# %%
from nltk import pos_tag

pos_tags = pos_tag(tokens)
print(pos_tags)
# Out:
# [('Text', 'NN'), ('analytics', 'NNS'), ('is', 'VBZ'), ('the', 'DT'), ('process', 'NN'), ('of', 'IN'), ('analyzing', 'VBG'), ('textual', 'JJ'), ('data', 'NNS'), ('to', 'TO'), ('extract', 'VB'), ('useful', 'JJ'), ('information', 'NN'), ('.', '.'), ('It', 'PRP'), ('includes', 'VBZ'), ('tokenization', 'NN'), (',', ','), ('stemming', 'VBG'), (',', ','), ('lemmatization', 'NN'), (',', ','), ('and', 'CC'), ('many', 'JJ'), ('other', 'JJ'), ('techniques', 'NNS'), ('.', '.')]

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

print("\nAfter Stopword Removal:\n", filtered_tokens)
# Out:
# After Stopword Removal:
#  ['Text', 'analytics', 'process', 'analyzing', 'textual', 'data', 'extract', 'useful', 'information', '.', 'includes', 'tokenization', ',', 'stemming', ',', 'lemmatization', ',', 'many', 'techniques', '.']

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_tokens]

print("\nStemmed Words:\n", stemmed_words)
# Out:
# Stemmed Words:
#  ['text', 'analyt', 'process', 'analyz', 'textual', 'data', 'extract', 'use', 'inform', '.', 'includ', 'token', ',', 'stem', ',', 'lemmat', ',', 'mani', 'techniqu', '.']

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]

print("\nLemmatized Words:\n", lemmatized_words)
# Out:
# Lemmatized Words:
#  ['Text', 'analytics', 'process', 'analyzing', 'textual', 'data', 'extract', 'useful', 'information', '.', 'includes', 'tokenization', ',', 'stemming', ',', 'lemmatization', ',', 'many', 'technique', '.']

# %%
from collections import Counter

tf = Counter(filtered_tokens)
print("\nTerm Frequency:\n", tf)
# Out:
# Term Frequency:
#  Counter({',': 3, '.': 2, 'Text': 1, 'analytics': 1, 'process': 1, 'analyzing': 1, 'textual': 1, 'data': 1, 'extract': 1, 'useful': 1, 'information': 1, 'includes': 1, 'tokenization': 1, 'stemming': 1, 'lemmatization': 1, 'many': 1, 'techniques': 1})

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [text]

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(documents)

print("\nFeature Names:\n", vectorizer.get_feature_names_out())
print("\nTF-IDF Matrix:\n", tfidf_matrix.toarray())
# Out:
# Feature Names:
#  ['analytics' 'analyzing' 'and' 'data' 'extract' 'includes' 'information'
#  'is' 'it' 'lemmatization' 'many' 'of' 'other' 'process' 'stemming'
#  'techniques' 'text' 'textual' 'the' 'to' 'tokenization' 'useful']
#
# TF-IDF Matrix:
#  [[0.21320072 0.21320072 0.21320072 0.21320072 0.21320072 0.21320072
#   0.21320072 0.21320072 0.21320072 0.21320072 0.21320072 0.21320072
#   0.21320072 0.21320072 0.21320072 0.21320072 0.21320072 0.21320072
#   0.21320072 0.21320072 0.21320072 0.21320072]]
