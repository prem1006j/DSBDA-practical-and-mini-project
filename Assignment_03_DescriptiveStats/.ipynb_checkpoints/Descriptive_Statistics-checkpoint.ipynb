# %%
import pandas as pd
import numpy as np

path = r"C:\Users\Prem Vilas Nikam\DSBDA practical and mini project\Assignment_03_DescriptiveStats\dataset\Mall_Customers.csv"
dt = pd.read_csv(path)

print(dt)
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
print(dt.isnull().sum())
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
print(dt.mean(numeric_only=True))
# Out:
# CustomerID                100.50
# Age                        38.85
# Annual Income (k$)         60.56
# Spending Score (1-100)     50.20
# dtype: float64

# %%
print(dt.loc[:, 'Age'].mean())
# Out:
# 38.85

# %%
print(dt.mean(axis=1).head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(dt.mean(axis=1).head())
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:14461, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   14380 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
#   14381 def mean(
#   14382     self,
#    (...)  14386     **kwargs,
# ...

# %%
print(dt.median(numeric_only=True))
# Out:
# CustomerID                100.5
# Age                        36.0
# Annual Income (k$)         61.5
# Spending Score (1-100)     50.0
# dtype: float64

# %%
print(dt.loc[:, 'Age'].median())
# Out:
# 36.0

# %%
print(dt.mode())
# Out:
#      CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1  Female  32.0                54.0                    42.0
# 1             2     NaN   NaN                78.0                     NaN
# 2             3     NaN   NaN                 NaN                     NaN
# 3             4     NaN   NaN                 NaN                     NaN
# 4             5     NaN   NaN                 NaN                     NaN
# ..          ...     ...   ...                 ...                     ...
# 195         196     NaN   NaN                 NaN                     NaN
# 196         197     NaN   NaN                 NaN                     NaN
# 197         198     NaN   NaN                 NaN                     NaN
# 198         199     NaN   NaN                 NaN                     NaN
# 199         200     NaN   NaN                 NaN                     NaN
#
# [200 rows x 5 columns]

# %%
print(dt.loc[:, 'Annual Income (k$)'].mode())
# Out:
# 0    54
# 1    78
# Name: Annual Income (k$), dtype: int64

# %%
print(dt.min(numeric_only=True))
# Out:
# CustomerID                 1
# Age                       18
# Annual Income (k$)        15
# Spending Score (1-100)     1
# dtype: int64

# %%
print(dt.loc[:, 'Age'].min(skipna=False))
# Out:
# 18

# %%
print(dt.max(numeric_only=True))
# Out:
# CustomerID                200
# Age                        70
# Annual Income (k$)        137
# Spending Score (1-100)     99
# dtype: int64

# %%
print(dt.loc[:, 'Age'].max(skipna=False))
# Out:
# 70

# %%
print(dt.std(numeric_only=True))
# Out:
# CustomerID                57.879185
# Age                       13.969007
# Annual Income (k$)        26.264721
# Spending Score (1-100)    25.823522
# dtype: float64

# %%
print(dt.loc[:, 'Age'].std(skipna=False))
# Out:
# 13.96900733155888

# %%
print(dt.max(numeric_only=True))
# Out:
# CustomerID                200
# Age                        70
# Annual Income (k$)        137
# Spending Score (1-100)     99
# dtype: int64

# %%
print(dt.std(numeric_only=True))
# Out:
# CustomerID                57.879185
# Age                       13.969007
# Annual Income (k$)        26.264721
# Spending Score (1-100)    25.823522
# dtype: float64

# %%
print(dt.loc[:, 'Age'].std(skipna=False))
# Out:
# 13.96900733155888

# %%
print(dt.std(axis=1)[0:5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\nanops.py:87, in disallow.__call__.<locals>._f(*args, **kwargs)
#      86 try:
# ---> 87     return f(*args, **kwargs)
#      88 except ValueError as e:
#      89     # we want to transform an object array
#      90     # ValueError message to the more typical TypeError
#      91     # e.g. this is normally a disallowed function on
#      92     # object arrays that contain strings
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\nanops.py:149, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     148 else:
# --> 149     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     151 return result
#
# ...

# %%
print(dt.groupby('Genre')['Age'].mean())
# Out:
# Genre
# Female    38.098214
# Male      39.806818
# Name: Age, dtype: float64

# %%
print(dt['Age'].quantile([0.25,0.5,0.75,0.9]))
# Out:
# 0.25    28.75
# 0.50    36.00
# 0.75    49.00
# 0.90    59.10
# Name: Age, dtype: float64

# %%
print(dt.var(numeric_only=True))
# Out:
# CustomerID                3350.000000
# Age                        195.133166
# Annual Income (k$)         689.835578
# Spending Score (1-100)     666.854271
# dtype: float64

# %%
print(dt.skew(numeric_only=True))
# Out:
# CustomerID                0.000000
# Age                       0.485569
# Annual Income (k$)        0.321843
# Spending Score (1-100)   -0.047220
# dtype: float64

# %%
print(dt.kurtosis(numeric_only=True))
# Out:
# CustomerID               -1.200000
# Age                      -0.671573
# Annual Income (k$)       -0.098487
# Spending Score (1-100)   -0.826629
# dtype: float64

# %%
print(dt.corr(numeric_only=True))
# Out:
#                         CustomerID       Age  Annual Income (k$)  \
# CustomerID                1.000000 -0.026763            0.977548
# Age                      -0.026763  1.000000           -0.012398
# Annual Income (k$)        0.977548 -0.012398            1.000000
# Spending Score (1-100)    0.013835 -0.327227            0.009903
#
#                         Spending Score (1-100)
# CustomerID                            0.013835
# Age                                  -0.327227
# Annual Income (k$)                    0.009903
# Spending Score (1-100)                1.000000

# %%
import matplotlib.pyplot as plt

dt['Age'].hist()
plt.title("Age Distribution")
plt.show()

# %%
import seaborn as sns

sns.boxplot(x=dt['Annual Income (k$)'])
plt.show()

# %%
sns.countplot(x=dt['Genre'])
plt.show()
